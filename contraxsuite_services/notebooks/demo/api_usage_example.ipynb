# %%
CONTRAX_URL = 'https://dev.contraxsuite.com'
USERNAME = 'Administrator'
PASSWORD = 'Administrator'
PROJECT_ID = 30
DOCUMENT_FN = 'test_doc.pdf'

# %%
import requests

# %%
# Login
# Further authorization goes via 'auth_token' cookie.

r = requests.post('{contrax_url}/rest-auth/login/'.format(contrax_url=CONTRAX_URL),
                  data = {'username':USERNAME, 'password': PASSWORD})
cookies = {'auth_token': r.cookies['auth_token']}
r
# Out:
# <Response [200]>

# %%
# Get project info (mostly to ensure the project exists)

r = requests.get('{contrax_url}/api/v1/project/projects/{project_id}'
                 .format(contrax_url=CONTRAX_URL, project_id=PROJECT_ID), cookies=cookies)
document_type_code = r.json()['type_data']['code']
document_type_uid = r.json()['type_data']['uid']
document_type_code
# Out:
# 'lease.LeaseDocument'

# %%
# Start an upload session
# Multiple file uploads can be started during one upload session and the overall progress can be tracked.

r = requests.post('{contrax_url}/api/v1/project/upload-session/'.format(contrax_url=CONTRAX_URL), 
                  cookies=cookies, data = {'project': PROJECT_ID})

upload_session_id = r.json()['uid']

r.json()
# Out:
# {'created_by': 1, 'project': 30, 'uid': 'b195826e-16e1-4108-812e-95da9ac942f6'}

# %%
# Upload a file.
# For multiple files - repeat this request for each file.

with open(DOCUMENT_FN, 'rb') as f:
    r = requests.post('{contrax_url}/api/v1/project/upload-session/{upload_session_id}/upload/'
                      .format(contrax_url=CONTRAX_URL, upload_session_id=upload_session_id),
                      cookies=cookies, 
                      files={'file': f},
                      data={'send_email_notifications': 'false'})
r.json()
# Out:
# 'Loaded'

# %%
# Track upload progress
# Repeat checking progress until the document is parsed
import time

while True:
    r = requests.get('{contrax_url}/api/v1/project/upload-session/{upload_session_id}/progress/'
                 .format(contrax_url=CONTRAX_URL, upload_session_id=upload_session_id), cookies=cookies)
    data = r.json()
    # Exit if bad status code or there are no upload/parsing tasks started at all or if the total progress >= 100%
    if r.status_code != 200 or not data['document_tasks_progress'] or data['document_tasks_progress_total'] >= 100:
        break
    else:
        time.sleep(2)

r.json()
# Out:
# {'document_tasks_progress': {'test_doc.pdf': {'document_id': 80,
#    'document_progress': 100.0,
#    'file_name': 'test_doc.pdf',
#    'file_size': 24062,
#    'task_progress_data': [{'file_name': 'test_doc.pdf',
#      'task_id': '40b6da6c-56d8-4366-8391-229de9aec95e',
#      'task_name': 'Load Documents',
#      'task_progress': 100,
#      'task_status': 'SUCCESS'}],
#    'tasks_overall_status': 'SUCCESS'}},
#  'document_tasks_progress_total': 100.0,
#  'documents_total_size': 24062,
#  'project_id': 30,
#  'session_status': 'Parsed'}

# %%
# Get project statistics
r = requests.get('{contrax_url}/api/v1/rawdb/project_stats/{project_id}/'
                 .format(contrax_url=CONTRAX_URL, project_id=PROJECT_ID), cookies=cookies)
r.json()
# Out:
# {'items': [],
#  'reviewed_documents': 0,
#  'time': 0.035933494567871094,
#  'total_documents': 1}

# %%
# Get document id, name and term for each document in the project sorting them by term (desc)
# To see all possible columns - remove "columns" param from the query.
# To add more filters use params similar to "where_calculated_term=>60", "where_calculated_term=<=60", "where_calculated_term=[50;60]",
r = requests.get('{contrax_url}/api/v1/rawdb/documents/{document_type_code}/?project_ids={project_id}&columns=document_id,document_name,calculated_term&order_by=calculated_term:desc'
                 .format(contrax_url=CONTRAX_URL, document_type_code=document_type_code, project_id=PROJECT_ID), 
                 cookies=cookies)
first_doc_id = r.json()['items'][0]['document_id']
r.json()
# Out:
# {'items': [{'calculated_term': None,
#    'document_id': 80,
#    'document_name': 'test_doc.pdf'}],
#  'limit': 200,
#  'time': 0.03664398193359375,
#  'total_documents': 1}

# %%
# Get fields of the concrete document from the project (document grid API)
# document_full_text is shortened here - see below for getting full document text
r = requests.get('{contrax_url}/api/v1/rawdb/documents/{document_type_code}/?where_document_name={doc_name}&columns=document_name,document_id'
                 .format(contrax_url=CONTRAX_URL, 
                         document_type_code=document_type_code, 
                         doc_name=DOCUMENT_FN), 
                 cookies=cookies)
first_doc_id=r.json()['items'][0]['document_id']
r.json()['items'][0]

# %%
# Get fields of the concrete document from the project (document grid API)
# document_full_text is shortened here - see below for getting full document text
r = requests.get('{contrax_url}/api/v1/rawdb/documents/{document_type_code}/?where_document_id={doc_id}'
                 .format(contrax_url=CONTRAX_URL, 
                         document_type_code=document_type_code, 
                         doc_id=first_doc_id), 
                 cookies=cookies)
r.json()['items'][0]
# Out:
# {'alterations_allowed': False,
#  'alterations_allowed_suggested': False,
#  'area_acres': None,
#  'area_acres_suggested': None,
#  'area_size_sq_ft': None,
#  'area_size_sq_ft_suggested': None,
#  'assignee_name': None,
#  'auto_renew': None,
#  'auto_renew_suggested': None,
#  'calculated_area_size_sq_ft': None,
#  'calculated_area_size_sq_ft_suggested': None,
#  'calculated_expiration_date': None,
#  'calculated_expiration_date_suggested': None,
#  'calculated_lease_type': 'gross',
#  'calculated_lease_type_suggested': 'gross',
#  'calculated_term': None,
#  'calculated_term_suggested': None,
#  'cluster_id': None,
#  'commencement_date': None,
#  'commencement_date_suggested': None,
#  'document_full_text': 'This is a test document for OCR.\n\nPlain Text ~ Tab Width: 8 ~ Ln 3, Col 81 ~ INS',
#  'document_full_text_length': 82,
#  'document_id': 80,
#  'document_is_reviewed': False,
#  'document_name': 'test_doc.pdf',
#  'document_title': None,
#  'expiration_date': None,
#  'expiration_date_suggested': None,
#  'landlord': None,
#  'landlord_suggested': None,
#  'lease_type': 'hellooo!!!!',
#  'lease_type_suggested': 'hellooo!!!!',
#  'max_currency_amount': None,
#  'max_currency_currency': None,
#  'max_date': None,
#  'mean_rent_per_month': None,
#  'mean_rent_per_month_suggested': None,
#  'min_date': None,
#  'parties': None,
#  'project_id': 30,
#  'property_address': None,
#  'property_address_suggested': None,
#  'property_type': None,
#  'property_type_suggested': None,
#  'renew_non_renew_notice_duration': None,
#  'renew_non_renew_notice_duration_suggested': None,
#  'rent_due_frequency': None,
#  'rent_due_frequency_suggested': None,
#  'security_deposit': None,
#  'security_deposit_suggested': None,
#  'status_name': 'Loaded',
#  'tenant': None,
#  'tenant_suggested': None,
#  'term': None,
#  'term_suggested': None}

# %%
# Get field schema - field uids, types, codes, names
# Will be required for understanding field UIDs in the document API request below
r = requests.get('{contrax_url}/api/v1/document/document-types/{doc_type_uid}/'
                 .format(contrax_url=CONTRAX_URL, doc_type_uid=document_type_uid), cookies=cookies)
r.json()
# Out:
# {'code': 'lease.LeaseDocument',
#  'editor_type': None,
#  'fields_data': [{'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'alterations_allowed',
#    'confidence': None,
#    'default': False,
#    'default_value': '',
#    'depends_on_fields': [],
#    'description': '',
#    'display_yes_no': True,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': '',
#    'modified_date': '2019-02-27T12:09:08.500421Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': False,
#    'title': 'Alterations Allowed',
#    'type': 'related_info',
#    'uid': 'fc611670-153a-4958-be5b-3a5996263f83',
#    'value_aware': False},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'area_acres',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.108000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Area (acres)',
#    'type': 'float',
#    'uid': '61c6ea2f-ad11-410d-a11f-8a6ac1edd0a5',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'area_size_sq_ft',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.141000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Area Size (sq. ft.)',
#    'type': 'float',
#    'uid': 'e323b09c-1de8-42fe-a4c5-96b44b7f44cc',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': ['Yes', 'No'],
#    'code': 'auto_renew',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': '',
#    'modified_date': '2019-01-24T14:18:53.380416Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Auto Renew',
#    'type': 'choice',
#    'uid': '7fe3134b-b744-4052-af2f-0dbe49093ccb',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'calculated_area_size_sq_ft',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': ['61c6ea2f-ad11-410d-a11f-8a6ac1edd0a5',
#     'e323b09c-1de8-42fe-a4c5-96b44b7f44cc'],
#    'description': None,
#    'display_yes_no': False,
#    'formula': 'area_size_sq_ft if area_size_sq_ft \\\r\nelse float(area_acres) / 43560.0 if area_acres \\\r\nelse None',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.114000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Area Size (sq. ft., calculated)',
#    'type': 'float',
#    'uid': '9503b796-afcb-4bef-a3c9-ca279fd33906',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'calculated_expiration_date',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': ['4dafbc9d-cf81-47d7-8b31-9a4ab292e58f',
#     '56416702-8b77-43f8-b3ab-d89ac0b33b3e',
#     '5490a5b2-ee21-4953-aeb1-b4c2ff54e554'],
#    'description': None,
#    'display_yes_no': False,
#    'formula': 'expiration_date if expiration_date \\\r\nelse commencement_date + datetime.timedelta(days=term) if term and commencement_date \\\r\nelse None',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.103000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Expiration Date (calculated)',
#    'type': 'date',
#    'uid': '0191ad4c-dc27-4491-831c-59e898fe275f',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': ['triple-Net', 'double-Net', 'single-Net', 'gross'],
#    'code': 'calculated_lease_type',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': ['16c85547-b501-4f31-a47a-304a22239bd0'],
#    'description': None,
#    'display_yes_no': False,
#    'formula': "'gross' if not lease_type \\\r\nelse 'triple-Net' if len(lease_type) >= 3 \\\r\nelse 'double-Net' if len(lease_type) >= 2 \\\r\nelse 'single-Net'",
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.119000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Lease Type (calculated)',
#    'type': 'choice',
#    'uid': '46debb2b-4087-448a-a6b9-c4612a63816c',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'calculated_term',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': ['4dafbc9d-cf81-47d7-8b31-9a4ab292e58f',
#     '56416702-8b77-43f8-b3ab-d89ac0b33b3e',
#     '5490a5b2-ee21-4953-aeb1-b4c2ff54e554'],
#    'description': None,
#    'display_yes_no': False,
#    'formula': 'term if term \\\r\nelse (expiration_date - commencement_date).days if  commencement_date and expiration_date \\\r\nelse None',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.097000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Term (calculated)',
#    'type': 'duration',
#    'uid': '14b3f4ae-78ba-4458-b6be-4d3aa5cc76a3',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'commencement_date',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': '',
#    'modified_date': '2019-02-27T12:10:33.599153Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Commencement Date',
#    'type': 'date',
#    'uid': '4dafbc9d-cf81-47d7-8b31-9a4ab292e58f',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'expiration_date',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:54.959000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Expiration Date',
#    'type': 'date',
#    'uid': '56416702-8b77-43f8-b3ab-d89ac0b33b3e',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'landlord',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:54.981000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Landlord (Lessor)',
#    'type': 'company',
#    'uid': '5cfa8a72-8ebd-47e6-9187-614f7d4e7e28',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': ['pay_taxes', 'pay_costs', 'pay_insurance'],
#    'code': 'lease_type',
#    'confidence': None,
#    'default': True,
#    'default_value': 'hellooo!!!!',
#    'depends_on_fields': [],
#    'description': '',
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2019-01-16T17:56:07.144858Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Lease Type',
#    'type': 'multi_choice',
#    'uid': '16c85547-b501-4f31-a47a-304a22239bd0',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'mean_rent_per_month',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': '',
#    'modified_date': '2019-01-25T11:10:45.090536Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Mean Rent Per Month',
#    'type': 'amount',
#    'uid': 'ee330bf4-8e9f-4b48-badc-64122f4ed982',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'property_address',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:54.970000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Property Address',
#    'type': 'address',
#    'uid': 'df250888-2ec8-4d8c-a291-5b75185e1b60',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': ['storage', 'office', 'land', 'retail', 'farming'],
#    'code': 'property_type',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.125000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Property Type',
#    'type': 'multi_choice',
#    'uid': '76d50814-5a77-4135-a4e2-ffffbd72ea7d',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'renew_non_renew_notice_duration',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.173000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Renew / Non-renew Notice Duration',
#    'type': 'duration',
#    'uid': '2dc16d29-f317-4ea1-9d6e-cfc0f3fd1140',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': ['monthly', 'annual', 'at once'],
#    'code': 'rent_due_frequency',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.157000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Rent Due Frequency',
#    'type': 'choice',
#    'uid': '01301fab-eae0-41cd-8220-5391dddf7ec1',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'security_deposit',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.162000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Security Deposit',
#    'type': 'amount',
#    'uid': '5df4acf8-7ec7-4e50-9ff0-1a60ae8cb183',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'tenant',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.151000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Tenant (Lessee)',
#    'type': 'company',
#    'uid': '35d6fb9f-881c-4108-b525-8dbbcabd7097',
#    'value_aware': True},
#   {'allow_values_not_specified_in_choices': False,
#    'category': None,
#    'choices': [],
#    'code': 'term',
#    'confidence': None,
#    'default': True,
#    'default_value': None,
#    'depends_on_fields': [],
#    'description': None,
#    'display_yes_no': False,
#    'formula': '',
#    'hidden_always': False,
#    'hide_until': None,
#    'modified_date': '2018-12-04T14:22:55.146000Z',
#    'order': 0,
#    'read_only': False,
#    'requires_text_annotations': True,
#    'title': 'Term',
#    'type': 'duration',
#    'uid': '5490a5b2-ee21-4953-aeb1-b4c2ff54e554',
#    'value_aware': True}],
#  'modified_date': '2018-08-17T14:04:58.242000Z',
#  'title': 'Lease Document',
#  'uid': '78425541-fe21-4ede-9445-ca88ceb3fc4c'}

# %%
# Get full document text and other info
# In this API fields are referenced by UIDs.
r = requests.get('{contrax_url}/api/v1/document/project/{project_id}/documents/{doc_id}/'
                 .format(contrax_url=CONTRAX_URL, 
                         document_type_code=document_type_code, 
                         project_id=PROJECT_ID,
                         doc_id=first_doc_id), 
                 cookies=cookies)
r.json()
# Out:
# {'assignee': None,
#  'assignee_data': None,
#  'available_assignees_data': [{'first_name': '',
#    'full_name': 'Administrator',
#    'last_name': '',
#    'photo': None,
#    'pk': 1,
#    'role': 1,
#    'username': 'Administrator'}],
#  'available_statuses_data': [{'code': 'loaded',
#    'group': 1,
#    'group_data': {'code': 'starting',
#     'is_active': True,
#     'name': 'Starting',
#     'order': 1,
#     'pk': 1},
#    'is_active': True,
#    'name': 'Loaded',
#    'order': 1,
#    'pk': 1},
#   {'code': 'not_started',
#    'group': 1,
#    'group_data': {'code': 'starting',
#     'is_active': True,
#     'name': 'Starting',
#     'order': 1,
#     'pk': 1},
#    'is_active': True,
#    'name': 'Not Started',
#    'order': 2,
#    'pk': 3},
#   {'code': 'in_review',
#    'group': 2,
#    'group_data': {'code': 'in_progress',
#     'is_active': True,
#     'name': 'In Progress',
#     'order': 2,
#     'pk': 2},
#    'is_active': True,
#    'name': 'In Review',
#    'order': 3,
#    'pk': 2},
#   {'code': 'completed',
#    'group': 3,
#    'group_data': {'code': 'final',
#     'is_active': False,
#     'name': 'Final',
#     'order': 3,
#     'pk': 3},
#    'is_active': False,
#    'name': 'Completed',
#    'order': 4,
#    'pk': 4},
#   {'code': 'excluded',
#    'group': 3,
#    'group_data': {'code': 'final',
#     'is_active': False,
#     'name': 'Final',
#     'order': 3,
#     'pk': 3},
#    'is_active': False,
#    'name': 'Excluded',
#    'order': 5,
#    'pk': 5}],
#  'description': 'b195826e-16e1-4108-812e-95da9ac942f6/test_doc.pdf',
#  'document_type': '78425541-fe21-4ede-9445-ca88ceb3fc4c',
#  'field_value_objects': {'46debb2b-4087-448a-a6b9-c4612a63816c': {'created_by': None,
#    'created_date': '2019-02-28T13:39:56.224184Z',
#    'document': 80,
#    'field': '46debb2b-4087-448a-a6b9-c4612a63816c',
#    'location_end': None,
#    'location_start': None,
#    'location_text': None,
#    'modified_by': None,
#    'modified_date': '2019-02-28T13:39:56.224210Z',
#    'pk': 1595,
#    'value': 'gross'}},
#  'field_values': {'01301fab-eae0-41cd-8220-5391dddf7ec1': None,
#   '01301fab-eae0-41cd-8220-5391dddf7ec1_suggested': None,
#   '0191ad4c-dc27-4491-831c-59e898fe275f': None,
#   '0191ad4c-dc27-4491-831c-59e898fe275f_suggested': None,
#   '14b3f4ae-78ba-4458-b6be-4d3aa5cc76a3': None,
#   '14b3f4ae-78ba-4458-b6be-4d3aa5cc76a3_suggested': None,
#   '16c85547-b501-4f31-a47a-304a22239bd0': None,
#   '16c85547-b501-4f31-a47a-304a22239bd0_suggested': None,
#   '2dc16d29-f317-4ea1-9d6e-cfc0f3fd1140': None,
#   '2dc16d29-f317-4ea1-9d6e-cfc0f3fd1140_suggested': None,
#   '35d6fb9f-881c-4108-b525-8dbbcabd7097': None,
#   '35d6fb9f-881c-4108-b525-8dbbcabd7097_suggested': None,
#   '46debb2b-4087-448a-a6b9-c4612a63816c': 'gross',
#   '46debb2b-4087-448a-a6b9-c4612a63816c_suggested': 'gross',
#   '4dafbc9d-cf81-47d7-8b31-9a4ab292e58f': None,
#   '4dafbc9d-cf81-47d7-8b31-9a4ab292e58f_suggested': None,
#   '5490a5b2-ee21-4953-aeb1-b4c2ff54e554': None,
#   '5490a5b2-ee21-4953-aeb1-b4c2ff54e554_suggested': None,
#   '56416702-8b77-43f8-b3ab-d89ac0b33b3e': None,
#   '56416702-8b77-43f8-b3ab-d89ac0b33b3e_suggested': None,
#   '5cfa8a72-8ebd-47e6-9187-614f7d4e7e28': None,
#   '5cfa8a72-8ebd-47e6-9187-614f7d4e7e28_suggested': None,
#   '5df4acf8-7ec7-4e50-9ff0-1a60ae8cb183': None,
#   '5df4acf8-7ec7-4e50-9ff0-1a60ae8cb183_suggested': None,
#   '61c6ea2f-ad11-410d-a11f-8a6ac1edd0a5': None,
#   '61c6ea2f-ad11-410d-a11f-8a6ac1edd0a5_suggested': None,
#   '76d50814-5a77-4135-a4e2-ffffbd72ea7d': None,
#   '76d50814-5a77-4135-a4e2-ffffbd72ea7d_suggested': None,
#   '7fe3134b-b744-4052-af2f-0dbe49093ccb': None,
#   '7fe3134b-b744-4052-af2f-0dbe49093ccb_suggested': None,
#   '9503b796-afcb-4bef-a3c9-ca279fd33906': None,
#   '9503b796-afcb-4bef-a3c9-ca279fd33906_suggested': None,
#   'df250888-2ec8-4d8c-a291-5b75185e1b60': {'address': None},
#   'df250888-2ec8-4d8c-a291-5b75185e1b60_suggested': {'address': None},
#   'e323b09c-1de8-42fe-a4c5-96b44b7f44cc': None,
#   'e323b09c-1de8-42fe-a4c5-96b44b7f44cc_suggested': None,
#   'ee330bf4-8e9f-4b48-badc-64122f4ed982': None,
#   'ee330bf4-8e9f-4b48-badc-64122f4ed982_suggested': None,
#   'fc611670-153a-4958-be5b-3a5996263f83': None,
#   'fc611670-153a-4958-be5b-3a5996263f83_suggested': None},
#  'file_size': 24062,
#  'full_text': '\nThis is a test document for OCR.\n\nPlain Text ~ Tab Width: 8 ~ Ln 3, Col 81 ~ INS\n',
#  'name': 'test_doc.pdf',
#  'notes': [],
#  'pk': 80,
#  'status': 1,
#  'status_data': {'code': 'loaded',
#   'group': 1,
#   'group_data': {'code': 'starting',
#    'is_active': True,
#    'name': 'Starting',
#    'order': 1,
#    'pk': 1},
#   'is_active': True,
#   'name': 'Loaded',
#   'order': 1,
#   'pk': 1},
#  'title': None}
